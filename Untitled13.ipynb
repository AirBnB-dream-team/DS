# %% [markdown]
# # Things to consider #
#
# #### Our target is cheapst price #
# #### If a user is creating a profile and adding a airbnb pad to their list, who is serivng that data. i could just pull a feature object from the front end that would be used to train a model but that would mean our model would be training every ping #

# %%
import pandas as pd

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
url ='https://raw.githubusercontent.com/AirBnB-dream-team/DS/master/listings.csv'
df2 = pd.read_csv(url, index_col=None, na_values=['NA'], sep=',', low_memory=False)

# %%
pd.set_option('display.max_columns', None)

# %%
df2.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2265  https://www.airbnb.com/rooms/2265  20191112224534   2019-11-13
# 1  5245  https://www.airbnb.com/rooms/5245  20191112224534   2019-11-13
# 2  5456  https://www.airbnb.com/rooms/5456  20191112224534   2019-11-13
# 3  5769  https://www.airbnb.com/rooms/5769  20191112224534   2019-11-13
# 4  6413  https://www.airbnb.com/rooms/6413  20191112224534   2019-11-13
#
#                                                 name  \
# 0   Zen-East in the Heart of Austin (monthly rental)
# 1  Eco friendly, Colorful, Clean, Cozy monthly share
# 2          Walk to 6th, Rainey St and Convention Ctr
# 3                                     NW Austin Room
# 4                      Gem of a Studio near Downtown
#
#                                              summary  \
# 0  Zen East is situated in a vibrant & diverse mu...
# 1  Situated in a vibrant & diverse multicultural ...
# 2  Great central  location for walking to Convent...
# 3                                                NaN
# 4  Great studio apartment, perfect for couples or...
#
#                                                space  \
# 0  This colorful and clean 1923 house was complet...
# 1  This green, colorful, clean and cozy house was...
# 2  Cute Private Studio apartment located in Willo...
# 3  Looking for a comfortable inexpensive room to ...
# 4  (License #114332) Large, contemporary studio a...
#
#                                          description experiences_offered  \
# 0  Zen East is situated in a vibrant & diverse mu...                none
# 1  Situated in a vibrant & diverse multicultural ...                none
# 2  Great central  location for walking to Convent...                none
# 3  Looking for a comfortable inexpensive room to ...                none
# 4  Great studio apartment, perfect for couples or...                none
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1                                                NaN
# 2  My neighborhood is ideally located if you want...
# 3  Quiet neighborhood with lots of trees and good...
# 4  Travis Heights is one of the oldest neighborho...
#
#                                                notes  \
# 0  A 2013 Genuine Buddy Scooter 125 may be availa...
# 1  Please note: A two story studio was built in t...
# 2  Parking on street requires a permit.  Permits ...
# 3                                                NaN
# 4  Our calendar only extends a few months. If you...
#
#                                              transit  \
# 0  5 min walk to Capitol Metro Rail (train that t...
# 1                                                NaN
# 2  Bus stop around the block.  Uber, Lyft, Ride, ...
# 3  We are approximately 16 miles from downtown Au...
# 4  Parking for our place is on the street, roughl...
#
#                                               access  \
# 0  Several local restaurants, small clubs, music ...
# 1                                                NaN
# 2                       Guests have access to patio.
# 3                             Gravel Parking Kitchen
# 4     Private patio with lounge chairs and umbrella.
#
#                                          interaction  \
# 0  Depending on your dates and arrival time, I am...
# 1  I should be available, upon your arrival, to a...
# 2  I am happy to welcome my guests and show them in.
# 3  We interact with our guests as little or as mu...
# 4  You may see us during your stay, but you'll ma...
#
#                                          house_rules  thumbnail_url  \
# 0  • Check-in time is 4 pm. Check out is 11 am. I...            NaN
# 1  A brief profile for all guests along with phot...            NaN
# 2  No Pets allowed.  No smoking in the room. No m...            NaN
# 3  I will need to see identification at check in....            NaN
# 4  Posted prices include the 9% in local occupanc...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/4740524/63...
# 1         NaN  https://a0.muscache.com/im/pictures/5167505/b3...
# 2         NaN  https://a0.muscache.com/im/pictures/14084884/b...
# 3         NaN  https://a0.muscache.com/im/pictures/23822033/a...
# 4         NaN  https://a0.muscache.com/im/pictures/349818/97e...
#
#    xl_picture_url  host_id                                 host_url  \
# 0             NaN     2466   https://www.airbnb.com/users/show/2466
# 1             NaN     2466   https://www.airbnb.com/users/show/2466
# 2             NaN     8028   https://www.airbnb.com/users/show/8028
# 3             NaN     8186   https://www.airbnb.com/users/show/8186
# 4             NaN    13879  https://www.airbnb.com/users/show/13879
#
#    host_name  host_since                 host_location  \
# 0      Paddy  2008-08-23  Austin, Texas, United States
# 1      Paddy  2008-08-23  Austin, Texas, United States
# 2     Sylvia  2009-02-16  Austin, Texas, United States
# 3  Elizabeth  2009-02-19  Austin, Texas, United States
# 4       Todd  2009-04-17  Austin, Texas, United States
#
#                                           host_about  host_response_time  \
# 0  I am a long time resident of Austin. I earned ...  within a few hours
# 1  I am a long time resident of Austin. I earned ...  within a few hours
# 2  I am a licensed Real Estate Broker and owner o...  within a few hours
# 3  We're easygoing professionals that enjoy meeti...      within an hour
# 4  We're a young family that likes to travel, we ...      within an hour
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   NaN                 t
# 1               100%                   NaN                 t
# 2               100%                   NaN                 t
# 3               100%                   NaN                 t
# 4               100%                   NaN                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/2466/profile_...
# 1  https://a0.muscache.com/im/users/2466/profile_...
# 2  https://a0.muscache.com/im/users/8028/profile_...
# 3  https://a0.muscache.com/im/users/8186/profile_...
# 4  https://a0.muscache.com/im/pictures/user/4f35e...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/2466/profile_...      East Downtown
# 1  https://a0.muscache.com/im/users/2466/profile_...      East Downtown
# 2  https://a0.muscache.com/im/users/8028/profile_...      East Downtown
# 3  https://a0.muscache.com/im/users/8186/profile_...  SW Williamson Co.
# 4  https://a0.muscache.com/im/pictures/user/4f35e...     Travis Heights
#
#    host_listings_count  host_total_listings_count  \
# 0                  3.0                        3.0
# 1                  3.0                        3.0
# 2                  1.0                        1.0
# 3                  1.0                        1.0
# 4                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 1   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 2               ['email', 'phone', 'reviews', 'kba']                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
#
#   host_identity_verified                     street      neighbourhood  \
# 0                      t  Austin, TX, United States      East Downtown
# 1                      t  Austin, TX, United States      East Downtown
# 2                      t  Austin, TX, United States      East Downtown
# 3                      t  Austin, TX, United States  SW Williamson Co.
# 4                      f  Austin, TX, United States     Travis Heights
#
#    neighbourhood_cleansed  neighbourhood_group_cleansed    city state zipcode  \
# 0                   78702                           NaN  Austin    TX   78702
# 1                   78702                           NaN  Austin    TX   78702
# 2                   78702                           NaN  Austin    TX   78702
# 3                   78729                           NaN  Austin    TX   78729
# 4                   78704                           NaN  Austin    TX   78704
#
#    market smart_location country_code        country  latitude  longitude  \
# 0  Austin     Austin, TX           US  United States  30.27750  -97.71398
# 1  Austin     Austin, TX           US  United States  30.27577  -97.71379
# 2  Austin     Austin, TX           US  United States  30.26112  -97.73448
# 3  Austin     Austin, TX           US  United States  30.45596  -97.78370
# 4  Austin     Austin, TX           US  United States  30.24829  -97.73726
#
#   is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0                 f         House  Entire home/apt             4        2.0
# 1                 t         House     Private room             2        1.0
# 2                 t    Guesthouse  Entire home/apt             3        1.0
# 3                 t         House     Private room             2        1.0
# 4                 t    Guesthouse  Entire home/apt             2        1.0
#
#    bedrooms  beds  bed_type  \
# 0       2.0   2.0  Real Bed
# 1       1.0   2.0  Real Bed
# 2       1.0   2.0  Real Bed
# 3       1.0   1.0  Real Bed
# 4       NaN   1.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $225.00
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $100.00
# 2  {TV,Wifi,"Air conditioning",Kitchen,"Pets live...          NaN   $95.00
# 3  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN   $40.00
# 4  {TV,"Cable TV",Internet,Wifi,"Air conditioning...        550.0   $99.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN          $500.00      $100.00                4
# 1          NaN           NaN          $500.00       $75.00                2
# 2          NaN           NaN          $100.00          NaN                2
# 3      $160.00           NaN              NaN          NaN                2
# 4      $700.00     $1,900.00              NaN       $50.00                2
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $30.00              30              90                      30
# 1       $35.00              30              60                      30
# 2       $45.00               2              90                       2
# 3        $0.00               1              14                       1
# 4       $25.00               3             365                       3
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                      30                      90                      90
# 1                      30                      60                      60
# 2                       2                      90                      90
# 3                       1                      14                      14
# 4                       3                     365                     365
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                    30.0                    90.0     3 months ago
# 1                    30.0                    60.0     5 months ago
# 2                     2.0                    90.0       6 days ago
# 3                     1.0                    14.0       2 days ago
# 4                     3.0                   365.0       5 days ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0                0                0
# 1                t                0                0                0
# 2                t               10               24               54
# 3                t                0                3               13
# 4                t               14               14               14
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                 0            2019-11-13                 24
# 1                 0            2019-11-13                  9
# 2               304            2019-11-13                508
# 3                13            2019-11-13                257
# 4                14            2019-11-13                104
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      1   2009-03-17  2019-03-16                  93.0
# 1                      0   2009-03-19  2018-03-14                  91.0
# 2                     47   2009-03-08  2019-10-28                  96.0
# 3                     19   2010-04-10  2019-11-03                  98.0
# 4                     23   2009-12-14  2019-11-05                  99.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                     9.0                       10.0                   10.0
# 1                    10.0                        8.0                   10.0
# 2                    10.0                       10.0                   10.0
# 3                    10.0                       10.0                   10.0
# 4                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     8.0                  9.0
# 1                          9.0                    10.0                  9.0
# 2                         10.0                    10.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                    10.0                 10.0
#
#   requires_license      license jurisdiction_names instant_bookable  \
# 0                f          NaN    {"Texas State"}                f
# 1                f          NaN    {"Texas State"}                f
# 2                f          NaN    {"Texas State"}                f
# 3                f          NaN    {"Texas State"}                f
# 4                f  32041657928    {"Texas State"}                t
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 3                        f                     moderate
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                t
# 3                             t                                t
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               3
# 1                               3
# 2                               1
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            2
# 2                                            1
# 3                                            0
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             1
# 2                                             0
# 3                                             1
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.18
# 1                                            0               0.07
# 2                                            0               3.90
# 3                                            0               2.20
# 4                                            0               0.86

# %%
print(df2.shape)
# Out:
# (11250, 106)

# %%
# for col, i in enumerate(list(df2.columns)):
#   row_name =  str(i) + '=' f'row[{str(col)}],'
#   print(row_name)

# %%
# for col in list(df2.columns):
#   row_name =  str(col) + ' = ' f"models.TextField(default='')"
#   print(row_name)

# %%
# !pip install category_encoders

# %%
df2.isna()
# Out:
#           id  listing_url  scrape_id  last_scraped   name  summary  space  \
# 0      False        False      False         False  False    False  False
# 1      False        False      False         False  False    False  False
# 2      False        False      False         False  False    False  False
# 3      False        False      False         False  False     True  False
# 4      False        False      False         False  False    False  False
# ...      ...          ...        ...           ...    ...      ...    ...
# 11245  False        False      False         False  False    False  False
# 11246  False        False      False         False  False    False  False
# 11247  False        False      False         False  False    False   True
# 11248  False        False      False         False  False    False   True
# 11249  False        False      False         False  False     True   True
#
#        description  experiences_offered  neighborhood_overview  notes  \
# 0            False                False                   True  False
# 1            False                False                   True  False
# 2            False                False                  False  False
# 3            False                False                  False   True
# 4            False                False                  False  False
# ...            ...                  ...                    ...    ...
# 11245        False                False                  False   True
# 11246        False                False                  False  False
# 11247        False                False                  False   True
# 11248        False                False                   True   True
# 11249         True                False                   True   True
#
#        transit  access  interaction  house_rules  thumbnail_url  medium_url  \
# 0        False   False        False        False           True        True
# 1         True    True        False        False           True        True
# 2        False   False        False        False           True        True
# 3        False   False        False        False           True        True
# 4        False   False        False        False           True        True
# ...        ...     ...          ...          ...            ...         ...
# 11245    False    True        False         True           True        True
# 11246     True    True        False        False           True        True
# 11247    False    True         True         True           True        True
# 11248     True    True        False         True           True        True
# 11249     True    True         True         True           True        True
#
#        picture_url  xl_picture_url  host_id  host_url  host_name  host_since  \
# 0            False            True    False     False      False       False
# 1            False            True    False     False      False       False
# 2            False            True    False     False      False       False
# 3            False            True    False     False      False       False
# 4            False            True    False     False      False       False
# ...            ...             ...      ...       ...        ...         ...
# 11245        False            True    False     False      False       False
# 11246        False            True    False     False      False       False
# 11247        False            True    False     False      False       False
# 11248        False            True    False     False      False       False
# 11249        False            True    False     False      False       False
#
#        host_location  host_about  host_response_time  host_response_rate  \
# 0              False       False               False               False
# 1              False       False               False               False
# 2              False       False               False               False
# 3              False       False               False               False
# 4              False       False               False               False
# ...              ...         ...                 ...                 ...
# 11245          False       False                True                True
# 11246          False        True               False               False
# 11247          False       False               False               False
# 11248          False       False               False               False
# 11249          False        True                True                True
#
#        host_acceptance_rate  host_is_superhost  host_thumbnail_url  \
# 0                      True              False               False
# 1                      True              False               False
# 2                      True              False               False
# 3                      True              False               False
# 4                      True              False               False
# ...                     ...                ...                 ...
# 11245                  True              False               False
# 11246                  True              False               False
# 11247                  True              False               False
# 11248                  True              False               False
# 11249                  True              False               False
#
#        host_picture_url  host_neighbourhood  host_listings_count  \
# 0                 False               False                False
# 1                 False               False                False
# 2                 False               False                False
# 3                 False               False                False
# 4                 False               False                False
# ...                 ...                 ...                  ...
# 11245             False               False                False
# 11246             False                True                False
# 11247             False                True                False
# 11248             False                True                False
# 11249             False                True                False
#
#        host_total_listings_count  host_verifications  host_has_profile_pic  \
# 0                          False               False                 False
# 1                          False               False                 False
# 2                          False               False                 False
# 3                          False               False                 False
# 4                          False               False                 False
# ...                          ...                 ...                   ...
# 11245                      False               False                 False
# 11246                      False               False                 False
# 11247                      False               False                 False
# 11248                      False               False                 False
# 11249                      False               False                 False
#
#        host_identity_verified  street  neighbourhood  neighbourhood_cleansed  \
# 0                       False   False          False                   False
# 1                       False   False          False                   False
# 2                       False   False          False                   False
# 3                       False   False          False                   False
# 4                       False   False          False                   False
# ...                       ...     ...            ...                     ...
# 11245                   False   False           True                   False
# 11246                   False   False           True                   False
# 11247                   False   False           True                   False
# 11248                   False   False           True                   False
# 11249                   False   False           True                   False
#
#        neighbourhood_group_cleansed   city  state  zipcode  market  \
# 0                              True  False  False    False   False
# 1                              True  False  False    False   False
# 2                              True  False  False    False   False
# 3                              True  False  False    False   False
# 4                              True  False  False    False   False
# ...                             ...    ...    ...      ...     ...
# 11245                          True  False  False    False   False
# 11246                          True  False  False    False   False
# 11247                          True  False  False    False   False
# 11248                          True  False  False    False   False
# 11249                          True  False  False    False   False
#
#        smart_location  country_code  country  latitude  longitude  \
# 0               False         False    False     False      False
# 1               False         False    False     False      False
# 2               False         False    False     False      False
# 3               False         False    False     False      False
# 4               False         False    False     False      False
# ...               ...           ...      ...       ...        ...
# 11245           False         False    False     False      False
# 11246           False         False    False     False      False
# 11247           False         False    False     False      False
# 11248           False         False    False     False      False
# 11249           False         False    False     False      False
#
#        is_location_exact  property_type  room_type  accommodates  bathrooms  \
# 0                  False          False      False         False      False
# 1                  False          False      False         False      False
# 2                  False          False      False         False      False
# 3                  False          False      False         False      False
# 4                  False          False      False         False      False
# ...                  ...            ...        ...           ...        ...
# 11245              False          False      False         False      False
# 11246              False          False      False         False      False
# 11247              False          False      False         False      False
# 11248              False          False      False         False      False
# 11249              False          False      False         False      False
#
#        bedrooms   beds  bed_type  amenities  square_feet  price  weekly_price  \
# 0         False  False     False      False         True  False          True
# 1         False  False     False      False         True  False          True
# 2         False  False     False      False         True  False          True
# 3         False  False     False      False         True  False         False
# 4          True  False     False      False        False  False         False
# ...         ...    ...       ...        ...          ...    ...           ...
# 11245     False  False     False      False         True  False          True
# 11246     False  False     False      False         True  False          True
# 11247     False  False     False      False         True  False          True
# 11248     False  False     False      False         True  False          True
# 11249     False  False     False      False         True  False          True
#
#        monthly_price  security_deposit  cleaning_fee  guests_included  \
# 0               True             False         False            False
# 1               True             False         False            False
# 2               True             False          True            False
# 3               True              True          True            False
# 4              False              True         False            False
# ...              ...               ...           ...              ...
# 11245           True              True          True            False
# 11246           True             False         False            False
# 11247           True             False         False            False
# 11248           True             False         False            False
# 11249           True              True          True            False
#
#        extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0             False           False           False                   False
# 1             False           False           False                   False
# 2             False           False           False                   False
# 3             False           False           False                   False
# 4             False           False           False                   False
# ...             ...             ...             ...                     ...
# 11245         False           False           False                   False
# 11246         False           False           False                   False
# 11247         False           False           False                   False
# 11248         False           False           False                   False
# 11249         False           False           False                   False
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       False                   False                   False
# 1                       False                   False                   False
# 2                       False                   False                   False
# 3                       False                   False                   False
# 4                       False                   False                   False
# ...                       ...                     ...                     ...
# 11245                   False                   False                   False
# 11246                   False                   False                   False
# 11247                   False                   False                   False
# 11248                   False                   False                   False
# 11249                   False                   False                   False
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                       False                   False             False
# 1                       False                   False             False
# 2                       False                   False             False
# 3                       False                   False             False
# 4                       False                   False             False
# ...                       ...                     ...               ...
# 11245                   False                   False             False
# 11246                   False                   False             False
# 11247                   False                   False             False
# 11248                   False                   False             False
# 11249                   False                   False             False
#
#        has_availability  availability_30  availability_60  availability_90  \
# 0                 False            False            False            False
# 1                 False            False            False            False
# 2                 False            False            False            False
# 3                 False            False            False            False
# 4                 False            False            False            False
# ...                 ...              ...              ...              ...
# 11245             False            False            False            False
# 11246             False            False            False            False
# 11247             False            False            False            False
# 11248             False            False            False            False
# 11249             False            False            False            False
#
#        availability_365  calendar_last_scraped  number_of_reviews  \
# 0                 False                  False              False
# 1                 False                  False              False
# 2                 False                  False              False
# 3                 False                  False              False
# 4                 False                  False              False
# ...                 ...                    ...                ...
# 11245             False                  False              False
# 11246             False                  False              False
# 11247             False                  False              False
# 11248             False                  False              False
# 11249             False                  False              False
#
#        number_of_reviews_ltm  first_review  last_review  review_scores_rating  \
# 0                      False         False        False                 False
# 1                      False         False        False                 False
# 2                      False         False        False                 False
# 3                      False         False        False                 False
# 4                      False         False        False                 False
# ...                      ...           ...          ...                   ...
# 11245                  False          True         True                  True
# 11246                  False          True         True                  True
# 11247                  False          True         True                  True
# 11248                  False          True         True                  True
# 11249                  False          True         True                  True
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
# ...                       ...                        ...
# 11245                    True                       True
# 11246                    True                       True
# 11247                    True                       True
# 11248                    True                       True
# 11249                    True                       True
#
#        review_scores_checkin  review_scores_communication  \
# 0                      False                        False
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
# ...                      ...                          ...
# 11245                   True                         True
# 11246                   True                         True
# 11247                   True                         True
# 11248                   True                         True
# 11249                   True                         True
#
#        review_scores_location  review_scores_value  requires_license  license  \
# 0                       False                False             False     True
# 1                       False                False             False     True
# 2                       False                False             False     True
# 3                       False                False             False     True
# 4                       False                False             False    False
# ...                       ...                  ...               ...      ...
# 11245                    True                 True             False     True
# 11246                    True                 True             False     True
# 11247                    True                 True             False     True
# 11248                    True                 True             False     True
# 11249                    True                 True             False     True
#
#        jurisdiction_names  instant_bookable  is_business_travel_ready  \
# 0                   False             False                     False
# 1                   False             False                     False
# 2                   False             False                     False
# 3                   False             False                     False
# 4                   False             False                     False
# ...                   ...               ...                       ...
# 11245               False             False                     False
# 11246               False             False                     False
# 11247               False             False                     False
# 11248               False             False                     False
# 11249               False             False                     False
#
#        cancellation_policy  require_guest_profile_picture  \
# 0                    False                          False
# 1                    False                          False
# 2                    False                          False
# 3                    False                          False
# 4                    False                          False
# ...                    ...                            ...
# 11245                False                          False
# 11246                False                          False
# 11247                False                          False
# 11248                False                          False
# 11249                False                          False
#
#        require_guest_phone_verification  calculated_host_listings_count  \
# 0                                 False                           False
# 1                                 False                           False
# 2                                 False                           False
# 3                                 False                           False
# 4                                 False                           False
# ...                                 ...                             ...
# 11245                             False                           False
# 11246                             False                           False
# 11247                             False                           False
# 11248                             False                           False
# 11249                             False                           False
#
#        calculated_host_listings_count_entire_homes  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 11245                                        False
# 11246                                        False
# 11247                                        False
# 11248                                        False
# 11249                                        False
#
#        calculated_host_listings_count_private_rooms  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
# ...                                             ...
# 11245                                         False
# 11246                                         False
# 11247                                         False
# 11248                                         False
# 11249                                         False
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            False              False
# 1                                            False              False
# 2                                            False              False
# 3                                            False              False
# 4                                            False              False
# ...                                            ...                ...
# 11245                                        False               True
# 11246                                        False               True
# 11247                                        False               True
# 11248                                        False               True
# 11249                                        False               True
#
# [11250 rows x 106 columns]

# %%
df2.fillna(value=0, inplace=True)

# %%
df2.fillna(value=0, inplace=True)

# %%
# df2
import pandas as pd
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
import numpy as np

from sklearn.model_selection import train_test_split

# %%
df2['price'] = df2.price.replace('\$|\,', '', regex=True).astype(float)

# %%
df2.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2265  https://www.airbnb.com/rooms/2265  20191112224534   2019-11-13
# 1  5245  https://www.airbnb.com/rooms/5245  20191112224534   2019-11-13
# 2  5456  https://www.airbnb.com/rooms/5456  20191112224534   2019-11-13
# 3  5769  https://www.airbnb.com/rooms/5769  20191112224534   2019-11-13
# 4  6413  https://www.airbnb.com/rooms/6413  20191112224534   2019-11-13
#
#                                                 name  \
# 0   Zen-East in the Heart of Austin (monthly rental)
# 1  Eco friendly, Colorful, Clean, Cozy monthly share
# 2          Walk to 6th, Rainey St and Convention Ctr
# 3                                     NW Austin Room
# 4                      Gem of a Studio near Downtown
#
#                                              summary  \
# 0  Zen East is situated in a vibrant & diverse mu...
# 1  Situated in a vibrant & diverse multicultural ...
# 2  Great central  location for walking to Convent...
# 3                                                  0
# 4  Great studio apartment, perfect for couples or...
#
#                                                space  \
# 0  This colorful and clean 1923 house was complet...
# 1  This green, colorful, clean and cozy house was...
# 2  Cute Private Studio apartment located in Willo...
# 3  Looking for a comfortable inexpensive room to ...
# 4  (License #114332) Large, contemporary studio a...
#
#                                          description experiences_offered  \
# 0  Zen East is situated in a vibrant & diverse mu...                none
# 1  Situated in a vibrant & diverse multicultural ...                none
# 2  Great central  location for walking to Convent...                none
# 3  Looking for a comfortable inexpensive room to ...                none
# 4  Great studio apartment, perfect for couples or...                none
#
#                                neighborhood_overview  \
# 0                                                  0
# 1                                                  0
# 2  My neighborhood is ideally located if you want...
# 3  Quiet neighborhood with lots of trees and good...
# 4  Travis Heights is one of the oldest neighborho...
#
#                                                notes  \
# 0  A 2013 Genuine Buddy Scooter 125 may be availa...
# 1  Please note: A two story studio was built in t...
# 2  Parking on street requires a permit.  Permits ...
# 3                                                  0
# 4  Our calendar only extends a few months. If you...
#
#                                              transit  \
# 0  5 min walk to Capitol Metro Rail (train that t...
# 1                                                  0
# 2  Bus stop around the block.  Uber, Lyft, Ride, ...
# 3  We are approximately 16 miles from downtown Au...
# 4  Parking for our place is on the street, roughl...
#
#                                               access  \
# 0  Several local restaurants, small clubs, music ...
# 1                                                  0
# 2                       Guests have access to patio.
# 3                             Gravel Parking Kitchen
# 4     Private patio with lounge chairs and umbrella.
#
#                                          interaction  \
# 0  Depending on your dates and arrival time, I am...
# 1  I should be available, upon your arrival, to a...
# 2  I am happy to welcome my guests and show them in.
# 3  We interact with our guests as little or as mu...
# 4  You may see us during your stay, but you'll ma...
#
#                                          house_rules  thumbnail_url  \
# 0  • Check-in time is 4 pm. Check out is 11 am. I...            0.0
# 1  A brief profile for all guests along with phot...            0.0
# 2  No Pets allowed.  No smoking in the room. No m...            0.0
# 3  I will need to see identification at check in....            0.0
# 4  Posted prices include the 9% in local occupanc...            0.0
#
#    medium_url                                        picture_url  \
# 0         0.0  https://a0.muscache.com/im/pictures/4740524/63...
# 1         0.0  https://a0.muscache.com/im/pictures/5167505/b3...
# 2         0.0  https://a0.muscache.com/im/pictures/14084884/b...
# 3         0.0  https://a0.muscache.com/im/pictures/23822033/a...
# 4         0.0  https://a0.muscache.com/im/pictures/349818/97e...
#
#    xl_picture_url  host_id                                 host_url  \
# 0             0.0     2466   https://www.airbnb.com/users/show/2466
# 1             0.0     2466   https://www.airbnb.com/users/show/2466
# 2             0.0     8028   https://www.airbnb.com/users/show/8028
# 3             0.0     8186   https://www.airbnb.com/users/show/8186
# 4             0.0    13879  https://www.airbnb.com/users/show/13879
#
#    host_name  host_since                 host_location  \
# 0      Paddy  2008-08-23  Austin, Texas, United States
# 1      Paddy  2008-08-23  Austin, Texas, United States
# 2     Sylvia  2009-02-16  Austin, Texas, United States
# 3  Elizabeth  2009-02-19  Austin, Texas, United States
# 4       Todd  2009-04-17  Austin, Texas, United States
#
#                                           host_about  host_response_time  \
# 0  I am a long time resident of Austin. I earned ...  within a few hours
# 1  I am a long time resident of Austin. I earned ...  within a few hours
# 2  I am a licensed Real Estate Broker and owner o...  within a few hours
# 3  We're easygoing professionals that enjoy meeti...      within an hour
# 4  We're a young family that likes to travel, we ...      within an hour
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   0.0                 t
# 1               100%                   0.0                 t
# 2               100%                   0.0                 t
# 3               100%                   0.0                 t
# 4               100%                   0.0                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/2466/profile_...
# 1  https://a0.muscache.com/im/users/2466/profile_...
# 2  https://a0.muscache.com/im/users/8028/profile_...
# 3  https://a0.muscache.com/im/users/8186/profile_...
# 4  https://a0.muscache.com/im/pictures/user/4f35e...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/2466/profile_...      East Downtown
# 1  https://a0.muscache.com/im/users/2466/profile_...      East Downtown
# 2  https://a0.muscache.com/im/users/8028/profile_...      East Downtown
# 3  https://a0.muscache.com/im/users/8186/profile_...  SW Williamson Co.
# 4  https://a0.muscache.com/im/pictures/user/4f35e...     Travis Heights
#
#    host_listings_count  host_total_listings_count  \
# 0                  3.0                        3.0
# 1                  3.0                        3.0
# 2                  1.0                        1.0
# 3                  1.0                        1.0
# 4                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 1   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 2               ['email', 'phone', 'reviews', 'kba']                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
#
#   host_identity_verified                     street      neighbourhood  \
# 0                      t  Austin, TX, United States      East Downtown
# 1                      t  Austin, TX, United States      East Downtown
# 2                      t  Austin, TX, United States      East Downtown
# 3                      t  Austin, TX, United States  SW Williamson Co.
# 4                      f  Austin, TX, United States     Travis Heights
#
#    neighbourhood_cleansed  neighbourhood_group_cleansed    city state zipcode  \
# 0                   78702                           0.0  Austin    TX   78702
# 1                   78702                           0.0  Austin    TX   78702
# 2                   78702                           0.0  Austin    TX   78702
# 3                   78729                           0.0  Austin    TX   78729
# 4                   78704                           0.0  Austin    TX   78704
#
#    market smart_location country_code        country  latitude  longitude  \
# 0  Austin     Austin, TX           US  United States  30.27750  -97.71398
# 1  Austin     Austin, TX           US  United States  30.27577  -97.71379
# 2  Austin     Austin, TX           US  United States  30.26112  -97.73448
# 3  Austin     Austin, TX           US  United States  30.45596  -97.78370
# 4  Austin     Austin, TX           US  United States  30.24829  -97.73726
#
#   is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0                 f         House  Entire home/apt             4        2.0
# 1                 t         House     Private room             2        1.0
# 2                 t    Guesthouse  Entire home/apt             3        1.0
# 3                 t         House     Private room             2        1.0
# 4                 t    Guesthouse  Entire home/apt             2        1.0
#
#    bedrooms  beds  bed_type  \
# 0       2.0   2.0  Real Bed
# 1       1.0   2.0  Real Bed
# 2       1.0   2.0  Real Bed
# 3       1.0   1.0  Real Bed
# 4       0.0   1.0  Real Bed
#
#                                            amenities  square_feet  price  \
# 0  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          0.0  225.0
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          0.0  100.0
# 2  {TV,Wifi,"Air conditioning",Kitchen,"Pets live...          0.0   95.0
# 3  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          0.0   40.0
# 4  {TV,"Cable TV",Internet,Wifi,"Air conditioning...        550.0   99.0
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0            0             0          $500.00      $100.00                4
# 1            0             0          $500.00       $75.00                2
# 2            0             0          $100.00            0                2
# 3      $160.00             0                0            0                2
# 4      $700.00     $1,900.00                0       $50.00                2
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $30.00              30              90                      30
# 1       $35.00              30              60                      30
# 2       $45.00               2              90                       2
# 3        $0.00               1              14                       1
# 4       $25.00               3             365                       3
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                      30                      90                      90
# 1                      30                      60                      60
# 2                       2                      90                      90
# 3                       1                      14                      14
# 4                       3                     365                     365
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                    30.0                    90.0     3 months ago
# 1                    30.0                    60.0     5 months ago
# 2                     2.0                    90.0       6 days ago
# 3                     1.0                    14.0       2 days ago
# 4                     3.0                   365.0       5 days ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0                0                0
# 1                t                0                0                0
# 2                t               10               24               54
# 3                t                0                3               13
# 4                t               14               14               14
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                 0            2019-11-13                 24
# 1                 0            2019-11-13                  9
# 2               304            2019-11-13                508
# 3                13            2019-11-13                257
# 4                14            2019-11-13                104
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      1   2009-03-17  2019-03-16                  93.0
# 1                      0   2009-03-19  2018-03-14                  91.0
# 2                     47   2009-03-08  2019-10-28                  96.0
# 3                     19   2010-04-10  2019-11-03                  98.0
# 4                     23   2009-12-14  2019-11-05                  99.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                     9.0                       10.0                   10.0
# 1                    10.0                        8.0                   10.0
# 2                    10.0                       10.0                   10.0
# 3                    10.0                       10.0                   10.0
# 4                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     8.0                  9.0
# 1                          9.0                    10.0                  9.0
# 2                         10.0                    10.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                    10.0                 10.0
#
#   requires_license      license jurisdiction_names instant_bookable  \
# 0                f            0    {"Texas State"}                f
# 1                f            0    {"Texas State"}                f
# 2                f            0    {"Texas State"}                f
# 3                f            0    {"Texas State"}                f
# 4                f  32041657928    {"Texas State"}                t
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 3                        f                     moderate
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                t
# 3                             t                                t
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               3
# 1                               3
# 2                               1
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            2
# 2                                            1
# 3                                            0
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             1
# 2                                             0
# 3                                             1
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.18
# 1                                            0               0.07
# 2                                            0               3.90
# 3                                            0               2.20
# 4                                            0               0.86

# %%
df2.price.dtype
# Out:
# dtype('float64')

# %%
# import plotly.express as px
# # px.scatter(df2, x='longitude', y='latitude', color='price', size=price, opacity=0.1)
# fig = px.scatter_mapbox(df2, lat='latitude', lon='longitude', color='zipcode', size="price",opacity=0.8)
# fig.update_layout(mapbox_style='stamen-terrain')
# fig.show()

# %%
df2['price'].plot.line()

# %%
from sklearn.impute import SimpleImputer
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
# def get_model_pred(request):
#     if request.method == 'GET':
#         data = data_choice[request.GET.get('dataset', 'MovieTrain')]
#         qs = data.objects.all()
#         df = qs.to_dataframe(fieldnames = data.features + data.target)

      
#         return JsonResponse(jdf, safe=False)
    



# def model_fit(data, target, features):
#   data.dropna(inplace=True)

#   trained_models = []
#   plot_pred = []

#   print(target, '\n', features)
  
#   mlp = make_pipeline(
      
#       StandardScaler(),
#       MLPRegressor(hidden_layer_sizes=(100, 100),
#       tol=1e-2, max_iter=500, random_state=0)

#       )
  
#   mlp.fit(data[features], data[target])
    
#   # y_true = list(data[target])
#   # y_pred = list(model.predict(data[features]))
#   # cleaned_data = [{"x": y_pred[index], "y": y_true[index]} for index in range(len(y_true))]
        
#   return True

# %%
df2['zipcode'] = df2['zipcode'].str.replace('TX ' , '')
# df2.dropna(inplace=True)
# df2.head()

# %%
features = ['bedrooms', 'bathrooms', 'minimum_nights', 'zipcode', 'host_neighbourhood']
target = 'weekly_price'

X = df2[features].copy()
y = df2['price'].copy()

# %%
y.head()
# Out:
# 0    225.0
# 1    100.0
# 2     95.0
# 3     40.0
# 4     99.0
# Name: price, dtype: float64

# %%
X.head()
# Out:
#    bedrooms  bathrooms  minimum_nights zipcode host_neighbourhood
# 0       2.0        2.0              30   78702      East Downtown
# 1       1.0        1.0              30   78702      East Downtown
# 2       1.0        1.0               2   78702      East Downtown
# 3       1.0        1.0               1   78729  SW Williamson Co.
# 4       0.0        1.0               3   78704     Travis Heights

# %%
X.minimum_nights.dtypes
# Out:
# dtype('int64')

# %%
# print(X.zipcode.dtype )
# X['zipcode'].value_counts()

# %%
# X[X['zipcode'].isnull()]

# %%
# X['zipcode'] = pd.to_numeric(X['zipcode'], errors='coerce')
# X = X.dropna(subset=['zipcode'])
# X['zipcode'] = X['zipcode'].astype(int)

# %%
# X.head()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
  trained_models = []
  plot_pred = []

  # print(target, '\n', features)
  
  mlp = make_pipeline(
      OneHotEncoder(),
      SimpleImputer(),
      StandardScaler(),
      MLPRegressor(hidden_layer_sizes=(100, 100),
      tol=1e-2, max_iter=500, random_state=0)

      )

# %%
mlp.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-fba0f5670a4b> in <module>
# ----> 1 mlp.fit(X_train, y_train)
#
# ~/.local/share/virtualenvs/flask_app--8d997RN/lib/python3.7/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     348             This estimator
#     349         """
# --> 350         Xt, fit_params = self._fit(X, y, **fit_params)
#     351         with _print_elapsed_time('Pipeline',
#     352                                  self._log_message(len(self.steps) - 1)):
#
# ~/.local/share/virtualenvs/flask_app--8d997RN/lib/python3.7/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params)
#     313                 message_clsname='Pipeline',
#     314                 message=self._log_message(step_idx),
# --> 315                 **fit_params_steps[name])
#     316             # Replace the transformer of the step with the fitted
#     317             # transformer. This is necessary when loading the transformer
#
# ~/.local/share/virtualenvs/flask_app--8d997RN/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# ~/.local/share/virtualenvs/flask_app--8d997RN/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     726     with _print_elapsed_time(message_clsname, message):
#     727         if hasattr(transformer, 'fit_transform'):
# --> 728             res = transformer.fit_transform(X, y, **fit_params)
#     729         else:
#     730             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~/.local/share/virtualenvs/flask_app--8d997RN/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py in fit_transform(self, X, y)
#     370         """
#     371         self._validate_keywords()
# --> 372         return super().fit_transform(X, y)
#     373
#     374     def transform(self, X):
#
# ~/.local/share/virtualenvs/flask_app--8d997RN/lib/python3.7/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
# --> 574             return self.fit(X, y, **fit_params).transform(X)
#     575
#     576
#
# ~/.local/share/virtualenvs/flask_app--8d997RN/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py in fit(self, X, y)
#     345         """
#     346         self._validate_keywords()
# --> 347         self._fit(X, handle_unknown=self.handle_unknown)
#     348         self.drop_idx_ = self._compute_drop_idx()
#     349         return self
#
# ~/.local/share/virtualenvs/flask_app--8d997RN/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py in _fit(self, X, handle_unknown)
#      72
#      73     def _fit(self, X, handle_unknown='error'):
# ---> 74         X_list, n_samples, n_features = self._check_X(X)
#      75
#      76         if self.categories != 'auto':
#
# ~/.local/share/virtualenvs/flask_app--8d997RN/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py in _check_X(self, X)
#      59             Xi = self._get_feature(X, feature_idx=i)
#      60             Xi = check_array(Xi, ensure_2d=False, dtype=None,
# ---> 61                              force_all_finite=needs_validation)
#      62             X_columns.append(Xi)
#      63
#
# ~/.local/share/virtualenvs/flask_app--8d997RN/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# ~/.local/share/virtualenvs/flask_app--8d997RN/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      63     elif X.dtype == np.dtype('object') and not allow_nan:
#      64         if _object_dtype_isnan(X).any():
# ---> 65             raise ValueError("Input contains NaN")
#      66
#      67
#
# ValueError: Input contains NaN

# %%
mlp.predict(X_test)

# %%
mlp.score( X_test, y_test)

# %%
import pickle
pickle.dump(mlp, open('model3.pkl', 'wb'))

# %%
import requests
import json

# %%
url = 'http://127.0.0.1:5000'
data = {  
    'bath_number': "3", 
    'bedrooms': 1, 
    'zipcode': 78619,
    'minimum_nights': 1,
    
}

data = json.dumps(data)

# %%
data

# %%
# from sklearn.inspection import plot_partial_dependence
# # fig, ax = plt.subplots(figsize=(12, 6))
# # ax.set_title("Multi-layer Perceptron")
# mlp_disp = plot_partial_dependence(mlp, X, features=features, feature_names=features, line_kw={"c": "red"})

# %%
pred = requests.post(url, data)
print(pred.json())

# %%
data = {  
    'bedrooms': 1, 
    'bathrooms': 1, 
    'zipcode': 78702,
       }

data = json.dumps(data)

# %%
pred_2 = requests.post(url, data)
print(pred_2.json())

# %%
data = {  
    'bedrooms': 1, 
    'bathrooms': 1, 
    'zipcode': 78704,
    'minimum_nights': 1,
    
       }

data = json.dumps(data)

# %%
pred_3 = requests.post(url, data)
print(pred_3.json())

# %%
# url = 'https://saveonairbnb.herokuapp.com/'
data = { 
    'minimum_nights': 1,
    
    'bedrooms': 10, 
    'bathrooms': 8, 
    'zipcode': 78702, 
       }

data = json.dumps(data)

# %%
data

# %%
pred_3 = requests.post(url, data)
print(pred_3.json())

# %%
100, 9, 78731
# url = 'https://saveonairbnb.herokuapp.com/'
data = {  
    'bedrooms': 2, 
    'bathrooms': 2,
    'minimum_nights': 2,
    'zipcode': 78702, 
    
       }

data = json.dumps(data)

# %%
pred_4 = requests.post(url, data)
print(pred_4.json())

# %%
722/800
